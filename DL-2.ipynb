# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# %%
# Load dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Normalize the pixel values from (0, 255) to (0, 1)
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# Flatten the images
train_images = train_images.reshape((train_images.shape[0], -1))
test_images = test_images.reshape((test_images.shape[0], -1))

# Convert class vectors to binary class matrices
train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)
# Out:
# ...
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
# Define the model
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
model.fit(train_images, train_labels, epochs=10, batch_size=128, verbose=1)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 9s 17ms/step - loss: 0.2241 - accuracy: 0.9336
# Epoch 2/10
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0818 - accuracy: 0.9751
# Epoch 3/10
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0537 - accuracy: 0.9831
# Epoch 4/10
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0366 - accuracy: 0.9881
# Epoch 5/10
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0259 - accuracy: 0.9913
# Epoch 6/10
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0225 - accuracy: 0.9924
# Epoch 7/10
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0183 - accuracy: 0.9937
# Epoch 8/10
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0164 - accuracy: 0.9943
# Epoch 9/10
# 469/469 [==============================] - 6s 14ms/step - loss: 0.0164 - accuracy: 0.9941
# Epoch 10/10
# ...

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=0)
print(f'Test accuracy: {test_acc:.3f}')
# Out:
# Test accuracy: 0.981

# %%
# Using the model to make predictions
predictions = model.predict(test_images)

# Display the model's prediction for the first image in the test dataset
print(f"Model's prediction for the first test image: {predictions[0]}")
# Out:
# 313/313 [==============================] - 1s 4ms/step
# Model's prediction for the first test image: [7.3215815e-13 4.1528947e-10 2.2087977e-10 2.6970224e-07 2.4614669e-13
#  2.2928970e-12 4.2768782e-16 9.9999970e-01 2.3562699e-12 1.9816822e-08]
